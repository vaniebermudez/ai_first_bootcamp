# %%
# !pip install openai==0.28.1
# !pip install fpdf==1.7.2
# Out:
# Requirement already satisfied: openai==0.28.1 in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28.1) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28.1) (4.66.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28.1) (3.10.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28.1) (2024.8.30)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28.1) (4.0.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->openai==0.28.1) (4.12.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->openai==0.28.1) (0.2.0)
# Collecting fpdf==1.7.2
#   Using cached fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=78eefbbf3ad21b5a7d3cec6cd58d9cca4373e02e0e7f530be2ed551823d12218
#   Stored in directory: /root/.cache/pip/wheels/f9/95/ba/f418094659025eb9611f17cbcaf2334236bf39a0c3453ea455
# Successfully built fpdf
# Installing collected packages: fpdf
# Successfully installed fpdf-1.7.2

# %%
import pandas as pd
import openai
import time
from fpdf import FPDF
import os

openai.api_key = ' '
os.environ['OPENAI_API_KEY'] = ' '

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/vaniebermudez/ai_first_bootcamp/refs/heads/main/Day4/inventory_products_dataset.csv')
df
# Out:
#     Product ID      Product Name      Category      SKU  \
# 0            1          Widget A      Hardware   WID123
# 1            2         Bolt Pack     Fasteners  BOLT456
# 2            3     Adhesive Tape      Supplies   TAP789
# 3            4    Safety Goggles   Safety Gear   SAF001
# 4            5      Welding Rods       Welding   WEL123
# 5            6     Drill Bit Set         Tools   DRI456
# 6            7   Electrical Wire    Electrical   ELE789
# 7            8            Hammer         Tools   HAM001
# 8            9    Paint Can (1L)        Paints   PAI123
# 9           10    Sandpaper Pack      Supplies   SAN456
# 10          11    Measuring Tape         Tools   TAP123
# 11          12     Gloves (Pair)   Safety Gear   GLO456
# 12          13        Wrench Set         Tools   WRE789
# 13          14  Steel Pipes (1m)      Hardware   PIP123
# 14          15   Screwdriver Set         Tools   SCR001
# 15          16        Mask (N95)   Safety Gear   MAS789
# 16          17   Aluminum Sheets  Raw Material   ALU123
# 17          18    PVC Pipes (2m)      Hardware   PVC456
# 18          19   Insulation Foam      Supplies   FOA789
# 19          20   Cable Ties Pack    Electrical   CAB001
#
#                    Description     Supplier Name  Quantity in Stock  \
# 0    High-quality metal widget      ABC Supplies                500
# 1        Set of 50 steel bolts     XYZ Fasteners                250
# 2     Industrial adhesive tape     TapeTech Inc.                150
# 3           Protective eyewear     SafeWare Ltd.                 75
# 4   High-strength welding rods   WeldCo Supplies                120
# 5       10-piece drill bit set  ToolMasters Inc.                200
# 6    100m spool of copper wire     Electra Corp.                400
# 7            Heavy-duty hammer   HammerWorks Co.                 90
# 8         1-liter can of paint        ColorWorld                300
# 9    Assorted sandpaper sheets        SmoothTech                500
# 10           5m measuring tape   MeasureMax Inc.                180
# 11       Durable safety gloves   HandShield Ltd.                 60
# 12          8-piece wrench set       FixIt Tools                 70
# 13          1-meter steel pipe    MetalWorks Co.                250
# 14   Precision screwdriver set      ToolHub Inc.                150
# 15         N95 protective mask  SafeBreath Corp.                300
# 16      1m x 1m aluminum sheet      AluForm Inc.                100
# 17            2-meter PVC pipe     PipeFlow Ltd.                 80
# 18     Thermal insulation foam    FoamGuard Ltd.                400
# 19      Pack of 100 cable ties     Electra Corp.                600
#
#     Reorder Level  Reorder Quantity Unit Price Total Inventory Value  \
# 0             100               200         $5                 $2500
# 1              50               100         $2                  $500
# 2              30                50         $3                  $450
# 3              20                50         $8                  $600
# 4              40                80        $10                 $1200
# 5              50               100        $15                 $3000
# 6             100               200        $20                 $8000
# 7              20                50         $7                  $630
# 8              75               150        $12                 $3600
# 9             100               250         $1                  $500
# 10             40                80         $4                  $720
# 11             20                30         $6                  $360
# 12             20                50        $18                 $1260
# 13             60               100        $25                 $6250
# 14             50                75         $9                 $1350
# 15             80               150         $2                  $600
# 16             30                50        $35                 $3500
# 17             20                40        $15                 $1200
# 18            100               200        $10                 $4000
# 19            150               300         $1                  $600
#
#        Location Date of Last Restock Lead Time Expiration Date Batch Number  \
# 0   Warehouse 1           11/01/2024    7 days             NaN     BATCH001
# 1   Warehouse 2           10/30/2024    5 days             NaN     BATCH002
# 2   Warehouse 3           11/05/2024    3 days             NaN     BATCH003
# 3   Warehouse 1           11/02/2024   10 days             NaN     BATCH004
# 4   Warehouse 2           11/01/2024   15 days             NaN     BATCH005
# 5   Warehouse 3           10/29/2024    8 days             NaN     BATCH006
# 6   Warehouse 1           11/04/2024   12 days             NaN     BATCH007
# 7   Warehouse 3           11/03/2024    5 days             NaN     BATCH008
# 8   Warehouse 2           11/01/2024   10 days      04/01/2025     BATCH009
# 9   Warehouse 1           11/06/2024    4 days             NaN     BATCH010
# 10  Warehouse 2           11/02/2024    7 days             NaN     BATCH011
# 11  Warehouse 3           10/28/2024    6 days             NaN     BATCH012
# 12  Warehouse 1           11/04/2024   14 days             NaN     BATCH013
# 13  Warehouse 2           10/31/2024   10 days             NaN     BATCH014
# 14  Warehouse 3           11/03/2024    5 days             NaN     BATCH015
# 15  Warehouse 1           11/05/2024    3 days      02/01/2025     BATCH016
# 16  Warehouse 2           10/30/2024   10 days             NaN     BATCH017
# 17  Warehouse 3           10/28/2024    8 days             NaN     BATCH018
# 18  Warehouse 1           11/04/2024    7 days      01/15/2025     BATCH019
# 19  Warehouse 2           11/02/2024    5 days             NaN     BATCH020
#
#    Condition Barcode
# 0        New   QR001
# 1        New   QR002
# 2        New   QR003
# 3        New   QR004
# 4        New   QR005
# 5        New   QR006
# 6        New   QR007
# 7        New   QR008
# 8        New   QR009
# 9        New   QR010
# 10       New   QR011
# 11       New   QR012
# 12       New   QR013
# 13       New   QR014
# 14       New   QR015
# 15       New   QR016
# 16       New   QR017
# 17       New   QR018
# 18       New   QR019
# 19       New   QR020

# %%
df.sample(5)
# Out:
#     Product ID     Product Name    Category     SKU  \
# 19          20  Cable Ties Pack  Electrical  CAB001
# 18          19  Insulation Foam    Supplies  FOA789
# 14          15  Screwdriver Set       Tools  SCR001
# 17          18   PVC Pipes (2m)    Hardware  PVC456
# 4            5     Welding Rods     Welding  WEL123
#
#                    Description    Supplier Name  Quantity in Stock  \
# 19      Pack of 100 cable ties    Electra Corp.                600
# 18     Thermal insulation foam   FoamGuard Ltd.                400
# 14   Precision screwdriver set     ToolHub Inc.                150
# 17            2-meter PVC pipe    PipeFlow Ltd.                 80
# 4   High-strength welding rods  WeldCo Supplies                120
#
#     Reorder Level  Reorder Quantity Unit Price Total Inventory Value  \
# 19            150               300         $1                  $600
# 18            100               200        $10                 $4000
# 14             50                75         $9                 $1350
# 17             20                40        $15                 $1200
# 4              40                80        $10                 $1200
#
#        Location Date of Last Restock Lead Time Expiration Date Batch Number  \
# 19  Warehouse 2           11/02/2024    5 days             NaN     BATCH020
# 18  Warehouse 1           11/04/2024    7 days      01/15/2025     BATCH019
# 14  Warehouse 3           11/03/2024    5 days             NaN     BATCH015
# 17  Warehouse 3           10/28/2024    8 days             NaN     BATCH018
# 4   Warehouse 2           11/01/2024   15 days             NaN     BATCH005
#
#    Condition Barcode
# 19       New   QR020
# 18       New   QR019
# 14       New   QR015
# 17       New   QR018
# 4        New   QR005

# %% [markdown]
# ## Understanding the Dataset

# %%
# Get Column Names and Data Types
column_info = df.dtypes.reset_index()
print(column_info, "\n")
# Out:
#                     index       0
# 0              Product ID   int64
# 1            Product Name  object
# 2                Category  object
# 3                     SKU  object
# 4             Description  object
# 5           Supplier Name  object
# 6       Quantity in Stock   int64
# 7           Reorder Level   int64
# 8        Reorder Quantity   int64
# 9              Unit Price  object
# 10  Total Inventory Value  object
# 11               Location  object
# 12   Date of Last Restock  object
# 13              Lead Time  object
# 14        Expiration Date  object
# 15           Batch Number  object
# 16              Condition  object
# 17                Barcode  object

# %%
# Identify Categorical and Numerical Features
categorical_features = df.select_dtypes(include=['object']).columns
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns

print("Categorical Features:", categorical_features)
print("Numerical Features:", numerical_features)
# Out:
# Categorical Features: Index(['Product Name', 'Category', 'SKU', 'Description', 'Supplier Name',
#        'Unit Price', 'Total Inventory Value', 'Location',
#        'Date of Last Restock', 'Lead Time', 'Expiration Date', 'Batch Number',
#        'Condition', 'Barcode'],
#       dtype='object')
# Numerical Features: Index(['Product ID', 'Quantity in Stock', 'Reorder Level', 'Reorder Quantity'], dtype='object')

# %%
# Get Unique Values for Categorical Features with Limitation
def get_unique_values(col, max_display=10):
    uniques = df[col].unique().tolist()
    if len(uniques) > max_display:
        return uniques[:max_display] + ["..."]
    return uniques

unique_values = {col: get_unique_values(col) for col in categorical_features}

print("Unique Values for Categorical Features:")
for col, uniques in unique_values.items():
    print(f" - {col}: {uniques}")
print()
# Out:
# Unique Values for Categorical Features:
#  - Product Name: ['Widget A', 'Bolt Pack', 'Adhesive Tape', 'Safety Goggles', 'Welding Rods', 'Drill Bit Set', 'Electrical Wire', 'Hammer', 'Paint Can (1L)', 'Sandpaper Pack', '...']
#  - Category: ['Hardware', 'Fasteners', 'Supplies', 'Safety Gear', 'Welding', 'Tools', 'Electrical', 'Paints', 'Raw Material']
#  - SKU: ['WID123', 'BOLT456', 'TAP789', 'SAF001', 'WEL123', 'DRI456', 'ELE789', 'HAM001', 'PAI123', 'SAN456', '...']
#  - Description: ['High-quality metal widget', 'Set of 50 steel bolts', 'Industrial adhesive tape', 'Protective eyewear', 'High-strength welding rods', '10-piece drill bit set', '100m spool of copper wire', 'Heavy-duty hammer', '1-liter can of paint', 'Assorted sandpaper sheets', '...']
#  - Supplier Name: ['ABC Supplies', 'XYZ Fasteners', 'TapeTech Inc.', 'SafeWare Ltd.', 'WeldCo Supplies', 'ToolMasters Inc.', 'Electra Corp.', 'HammerWorks Co.', 'ColorWorld', 'SmoothTech', '...']
#  - Unit Price: ['$5', '$2', '$3', '$8', '$10', '$15', '$20', '$7', '$12', '$1', '...']
#  - Total Inventory Value: ['$2500', '$500', '$450', '$600', '$1200', '$3000', '$8000', '$630', '$3600', '$720', '...']
#  - Location: ['Warehouse 1', 'Warehouse 2', 'Warehouse 3']
#  - Date of Last Restock: ['11/01/2024', '10/30/2024', '11/05/2024', '11/02/2024', '10/29/2024', '11/04/2024', '11/03/2024', '11/06/2024', '10/28/2024', '10/31/2024']
#  - Lead Time: ['7 days', '5 days', '3 days', '10 days', '15 days', '8 days', '12 days', '4 days', '6 days', '14 days']
#  - Expiration Date: [nan, '04/01/2025', '02/01/2025', '01/15/2025']
#  - Batch Number: ['BATCH001', 'BATCH002', 'BATCH003', 'BATCH004', 'BATCH005', 'BATCH006', 'BATCH007', 'BATCH008', 'BATCH009', 'BATCH010', '...']
#  - Condition: ['New']
#  - Barcode: ['QR001', 'QR002', 'QR003', 'QR004', 'QR005', 'QR006', 'QR007', 'QR008', 'QR009', 'QR010', '...']

# %%
# Get Descriptive Statistics for Numerical Features

numerical_stats = df[numerical_features].describe()
print(numerical_stats)
# Out:
#        Product ID  Quantity in Stock  Reorder Level  Reorder Quantity
# count    20.00000          20.000000      20.000000         20.000000
# mean     10.50000         238.750000      57.750000        115.250000
# std       5.91608         164.699687      36.937892         77.891203
# min       1.00000          60.000000      20.000000         30.000000
# 25%       5.75000          97.500000      27.500000         50.000000
# 50%      10.50000         190.000000      50.000000         90.000000
# 75%      15.25000         325.000000      85.000000        162.500000
# max      20.00000         600.000000     150.000000        300.000000

# %% [markdown]
# ## Generating the Template

# %%
def generate_template(df,
                             column_info,
                             categorical_features,
                             numerical_features,
                             unique_values,
                             numerical_stats):

    # Construct a summary of the dataframe's structure
    column_summary = "Column Names and Data Types: \n"
    for col, dtype in zip(df.columns, df.dtypes):
        column_summary += f"{col}: {dtype}\n"

    # Unique values for categorical features
    unique_values_str = "Unique Values for Categorical Features: \n"
    for col, uniques in unique_values.items():
        unique_values_str += f" - {col}: {uniques}\n"


    # Descriptive statistics for numerical features
    numerical_stats_str = "Descriptive Statistics for Numerical Features: \n"
    for col in numerical_features:
        numerical_stats_str += f" - {col}:\n"
        for stat_name, value in numerical_stats[col].items():
            numerical_stats_str += f"   {stat_name}: {value}\n"

    # Define the system prompt
    system_prompt = """
    You are an intelligent assistant that creates descriptive templates for transforming dataframe rows into coherent paragraphs.
    Analyze the provided dataframe structure and generate a template sentence that includes placeholders for each column.
    Ensure the template is contextually relevant and maintains grammatical correctness
    """

    # Define the user prompt
    user_prompt = f"""
    Analyze the following dataframe structure and create a descriptive template with placeholders for each column.

    <column_summary>
    {column_summary}
    </column_summary>

    <unique_values>
    {unique_values_str}
    </unique_values>

    <numerical_stats>
    {numerical_stats_str}
    </numerical_stats>

    Use the exact column names from the column_summary in generating the variable names in the template,
    as they will be populated with the actual values in the dataset.

    Example Template about a Spotify dataset:
    "{{artist}} gained {{streams}} streams in the song '{{song}}' that was a hit in {{date}}."


Output only the template without any explanation or introduction.
The template's variables will be dynamically replaced so make sure they're formatted properly."""


    # Generate the template (with retries)
    system_prompt = """You are an intelligent assistant that creates descriptive templates for transforming dataframe rows into coherent paragraphs.
    Analyze the provided dataframe structure and generate a template sentence that includes placeholders for each column.
    Ensure the template is contextually relevant and maintains grammatical correctness."""

    retries = 3
    for attempt in range(retries):
        try:
            response = openai.ChatCompletion.create(
                model="gpt-4o-mini",
                temperature=0.3,
                max_tokens=1024,
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_prompt}
                ]
            )
            template = response['choices'][0]['message']['content'].strip()
            return template
        except Exception as e:
            print(f"Error generating template (Attempt {attempt + 1}/{retries}): {e}")
            time.sleep(2)  # Wait before retrying

    return None

# %%
# Generate the template
template = generate_template(df,
                             column_info,
                             categorical_features,
                             numerical_features,
                             unique_values,
                             numerical_stats)
print(template)
# Out:
# "The product '{Product Name}' (SKU: {SKU}), categorized under '{Category}', is supplied by '{Supplier Name}'. It has a total quantity of {Quantity in Stock} in stock, with a reorder level set at {Reorder Level} and a reorder quantity of {Reorder Quantity}. Priced at {Unit Price}, the total inventory value amounts to {Total Inventory Value}. This product is located in {Location} and was last restocked on {Date of Last Restock}. The lead time for this product is {Lead Time}, and it is in '{Condition}' condition. The expiration date is {Expiration Date}, and it belongs to batch number {Batch Number} with barcode {Barcode}."

# %% [markdown]
# ## Populating the Template with Actual Values

# %%
def populate_template(template, row):

    # Convert row to dictionary and replace NaN with 'N/A'
    row_dict = row.to_dict()
    for key, value in row_dict.items():
      if pd.isna(value):
        row_dict[key] = 'N/A'
    # Generate the populated template per row

    paragraph = template.format(**row_dict)

    return paragraph

# %%
# Apply the populate_template function to each row in the dataframe
df['paragraph'] = df.apply(lambda row: populate_template(template, row), axis=1)

# %%
df['paragraph'][0]
# Out:
# '"The product \'Widget A\' (SKU: WID123), categorized under \'Hardware\', is supplied by \'ABC Supplies\'. It has a total quantity of 500 in stock, with a reorder level set at 100 and a reorder quantity of 200. Priced at $5, the total inventory value amounts to $2500. This product is located in Warehouse 1 and was last restocked on 11/01/2024. The lead time for this product is 7 days, and it is in \'New\' condition. The expiration date is N/A, and it belongs to batch number BATCH001 with barcode QR001."'

# %%
df.sample(5)
# Out:
#     Product ID    Product Name   Category      SKU  \
# 4            5    Welding Rods    Welding   WEL123
# 8            9  Paint Can (1L)     Paints   PAI123
# 7            8          Hammer      Tools   HAM001
# 12          13      Wrench Set      Tools   WRE789
# 1            2       Bolt Pack  Fasteners  BOLT456
#
#                    Description    Supplier Name  Quantity in Stock  \
# 4   High-strength welding rods  WeldCo Supplies                120
# 8         1-liter can of paint       ColorWorld                300
# 7            Heavy-duty hammer  HammerWorks Co.                 90
# 12          8-piece wrench set      FixIt Tools                 70
# 1        Set of 50 steel bolts    XYZ Fasteners                250
#
#     Reorder Level  Reorder Quantity Unit Price Total Inventory Value  \
# 4              40                80        $10                 $1200
# 8              75               150        $12                 $3600
# 7              20                50         $7                  $630
# 12             20                50        $18                 $1260
# 1              50               100         $2                  $500
#
#        Location Date of Last Restock Lead Time Expiration Date Batch Number  \
# 4   Warehouse 2           11/01/2024   15 days             NaN     BATCH005
# 8   Warehouse 2           11/01/2024   10 days      04/01/2025     BATCH009
# 7   Warehouse 3           11/03/2024    5 days             NaN     BATCH008
# 12  Warehouse 1           11/04/2024   14 days             NaN     BATCH013
# 1   Warehouse 2           10/30/2024    5 days             NaN     BATCH002
#
#    Condition Barcode                                          paragraph
# 4        New   QR005  "The product 'Welding Rods' (SKU: WEL123), cat...
# 8        New   QR009  "The product 'Paint Can (1L)' (SKU: PAI123), c...
# 7        New   QR008  "The product 'Hammer' (SKU: HAM001), categoriz...
# 12       New   QR013  "The product 'Wrench Set' (SKU: WRE789), categ...
# 1        New   QR002  "The product 'Bolt Pack' (SKU: BOLT456), categ...

# %% [markdown]
# ## Saving the Populated Templates (Natural Language Texts)

# %%
def save_content_to_txt(paragraphs, txt_filename):
    try:
        with open(txt_filename, 'w', encoding='utf-8') as file:

            for para in paragraphs:
                file.write(para + '\n\n')  # Double newline for separation

        print(f"All content has been saved as '{txt_filename}'.\n")
    except Exception as e:
        print(f"Error saving content to text file: {e}")

# %%
def save_content_to_pdf(paragraphs, pdf_filename):
    try:
        pdf = FPDF()
        pdf.add_page()
        pdf.set_auto_page_break(auto=True, margin=15)
        pdf.set_font("Arial", size=12)

        # Add each paragraph
        for para in paragraphs:
            pdf.multi_cell(0, 10, para)
            pdf.ln()  # Add a line break between paragraphs

        pdf.output(pdf_filename)
        print(f"All content has been saved as '{pdf_filename}'.\n")
    except Exception as e:
        print(f"Error saving content to PDF: {e}")

# %%
# Save the paragraphs to both text and PDF files
save_content_to_txt(df['paragraph'].to_list(), 'invy_nlg.txt')
save_content_to_pdf(df['paragraph'].to_list(), 'invy_nlg.pdf')
# Out:
# All content has been saved as 'invy_nlg.txt'.
#
# All content has been saved as 'invy_nlg.pdf'.
